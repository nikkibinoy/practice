# %% [markdown]
# <a href="https://colab.research.google.com/github/nikkibinoy/practice/blob/main/Exit_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Employee.csv')
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
df.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# ...

# %%
df.shape
# Out:
# (74498, 24)

# %% [markdown]
# **handling missing values**

# %%
df.isna().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        5
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        6
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  object
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  object
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74494 non-null  object
#  7   Job Satisfaction          74498 non-null  object
#  8   Performance Rating        74494 non-null  object
#  9   Number of Promotions      74493 non-null  float64
#  10  Overtime                  74498 non-null  object
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74493 non-null  object
# ...

# %%
df['Work-Life Balance'].fillna(df['Work-Life Balance'].mode()[0],inplace=True)
df['Performance Rating'].fillna(df['Performance Rating'].mode()[0],inplace=True)
df['Education Level'].fillna(df['Education Level'].mode()[0],inplace=True)
df['Marital Status'].fillna(df['Marital Status'].mode()[0],inplace=True)
df['Job Level'].fillna(df['Job Level'].mode()[0],inplace=True)
df['Company Size'].fillna(df['Company Size'].mode()[0],inplace=True)
df['Remote Work'].fillna(df['Remote Work'].mode()[0],inplace=True)
df['Employee Recognition'].fillna(df['Employee Recognition'].mode()[0],inplace=True)

# %%
df['Number of Promotions'].fillna(df['Number of Promotions'].mean(),inplace=True)
df['Number of Dependents'].fillna(df['Number of Dependents'].mean(),inplace=True)

# %% [markdown]
# #Visualization

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Job Role', hue='Gender', palette='pastel')
plt.title('Gender Distribution across Job Roles')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=10, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Job Satisfaction', hue='Attrition', palette='viridis')
plt.title('Attrition Rate by Job Satisfaction')
plt.show()

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Work-Life Balance', hue='Attrition', palette='cividis')
plt.title('Attrition Rate by Work-Life Balance')
plt.show()

# %%
sns.histplot(df['Monthly Income'], kde=True, bins=30, color='salmon')
plt.title('Distribution of Monthly Income')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  Attrition by Gender and Job Role

# %%
plt.figure(figsize=(14, 6))
sns.countplot(data=df, x='Job Role', hue='Attrition', palette='Set1')
plt.title('Attrition by Job Role')
plt.xticks(rotation=45)
plt.show()

# Gender Distribution by Job Role
plt.figure(figsize=(14, 6))
sns.countplot(data=df, x='Job Role', hue='Gender', palette='Set2')
plt.title('Gender Distribution by Job Role')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Overtime', hue='Attrition', palette='cividis')
plt.title('Count of Overtime vs. Attrition')
plt.show()

# %%
plt.figure(figsize=(12, 8))
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Heatmap for Numerical Features')
plt.show()

# %%
df.isna().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
df.nunique()
# Out:
# Employee ID                 74498
# Age                            42
# Gender                          2
# Years at Company               51
# Job Role                        5
# Monthly Income               9842
# Work-Life Balance               4
# Job Satisfaction                4
# Performance Rating              4
# Number of Promotions            6
# Overtime                        2
# Distance from Home             99
# Education Level                 5
# Marital Status                  3
# Number of Dependents            8
# Job Level                       3
# Company Size                    3
# Company Tenure                127
# Remote Work                     2
# Leadership Opportunities        2
# Innovation Opportunities        2
# Company Reputation              4
# Employee Recognition            4
# Attrition                       2
# dtype: int64

# %%
df.drop('Employee ID',axis=1,inplace=True)

# %%
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
outliers =['Monthly Income','Years at Company']

# %%
q1=df[outliers].quantile(0.25)
q3=df[outliers].quantile(0.75)
iqr=q3-q1

lower_bound=q1-(1.5*iqr)
upper_bound=q3+(1.5*iqr)

df=df[~((df[outliers]<(lower_bound))|(df[outliers]>(upper_bound))).any(axis=1)]

# %%
numerical_col=[col for col in df.columns if df[col].dtype!='O']
numerical_col
# Out:
# ['Age',
#  'Years at Company',
#  'Monthly Income',
#  'Number of Promotions',
#  'Distance from Home',
#  'Number of Dependents',
#  'Company Tenure']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
for col in numerical_col:
  df[col]=ss.fit_transform(df[[col]])

# %%
cat_col=[col for col in df.columns if df[col].dtype=='O']
cat_col
# Out:
# ['Gender',
#  'Job Role',
#  'Work-Life Balance',
#  'Job Satisfaction',
#  'Performance Rating',
#  'Overtime',
#  'Education Level',
#  'Marital Status',
#  'Job Level',
#  'Company Size',
#  'Remote Work',
#  'Leadership Opportunities',
#  'Innovation Opportunities',
#  'Company Reputation',
#  'Employee Recognition',
#  'Attrition']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in cat_col:
  df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#             Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0     -0.618109       1          0.311112         0       -0.887991
# 1      1.707605       0         -1.049752         3       -0.820817
# 2     -1.199537       0         -0.505406         2        0.403699
# 3     -0.202803       0         -0.777579         0       -1.541533
# 4      1.458421       1          2.307046         0       -1.153419
# ...         ...     ...               ...       ...             ...
# 74492  1.126176       1         -0.233233         4        0.934090
# 74493  1.458421       0          2.397770         2        0.250226
# 74494 -0.701170       0         -0.051785         0       -1.603575
# 74495  1.126176       1         -0.959028         0       -0.764839
# 74496 -1.697905       1         -1.049752         0       -0.941170
#
#        Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0                      0                 2                   0
# ...

# %%
df.describe()
# Out:
#                 Age        Gender  Years at Company      Job Role  \
# count  7.409500e+04  74095.000000      7.409500e+04  74095.000000
# mean   1.414708e-16      0.548121      6.271610e-17      2.119306
# std    1.000007e+00      0.497682      1.000007e+00      1.471677
# min   -1.697905e+00      0.000000     -1.321925e+00      0.000000
# 25%   -8.672926e-01      0.000000     -7.775791e-01      1.000000
# 50%   -3.668055e-02      1.000000     -2.332334e-01      2.000000
# 75%    8.769927e-01      1.000000      6.740093e-01      4.000000
# max    1.707605e+00      1.000000      2.851392e+00      4.000000
#
#        Monthly Income  Work-Life Balance  Job Satisfaction  \
# count    7.409500e+04       74095.000000      74095.000000
# mean     1.507967e-16           1.476348          1.102247
# std      1.000007e+00           0.942630          1.223093
# min     -2.830424e+00           0.000000          0.000000
# 25%     -7.662389e-01           1.000000          0.000000
# ...

# %%
x=df.drop('Attrition',axis=1)
y=df['Attrition']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((51866, 22), (22229, 22), (51866,), (22229,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
lr_acc=accuracy_score(y_test,y_pred_lr)
lr_acc
# Out:
# 0.7077241441360385

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred_dt=dt.predict(x_test)

dt_acc=accuracy_score(y_test,y_pred_dt)
dt_acc
# Out:
# 0.6598137568041748

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred_rf=rf.predict(x_test)

rf_acc=accuracy_score(y_test,y_pred_rf)
rf_acc
# Out:
# 0.7416887849205992

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred_knn=knn.predict(x_test)

knn_acc=accuracy_score(y_test,y_pred_knn)
knn_acc
# Out:
# 0.6446983669980656

# %%
nb=GaussianNB()
nb.fit(x_train,y_train)
y_pred_nb=nb.predict(x_test)

nb_acc=accuracy_score(y_test,y_pred_nb)
nb_acc
# Out:
# 0.699266723649287

# %%
model_names=['Logistic Regression','Decision Tree','Random Forest','KNN','Naive Bayes']
accuracy_scores=[lr_acc,dt_acc,rf_acc,knn_acc,nb_acc]

plt.figure(figsize=(10, 6))
sns.barplot(x=model_names, y=accuracy_scores, palette='viridis')
plt.title('Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.show()
# Out:
# <ipython-input-40-168aee7bc671>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=model_names, y=accuracy_scores, palette='viridis')

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 1    38894
# 0    35201
# Name: count, dtype: int64

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73     10682
#            1       0.75      0.76      0.75     11547
#
#     accuracy                           0.74     22229
#    macro avg       0.74      0.74      0.74     22229
# weighted avg       0.74      0.74      0.74     22229

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_rf)
print(cm)
# Out:
# [[7748 2934]
#  [2808 8739]]

# %%
from sklearn.model_selection import cross_val_score
model = RandomForestClassifier()
scores = cross_val_score(model,x, y, cv=5) # 5-fold cross-validation

print(scores)
# Out:
# [0.7437074  0.74600175 0.7437074  0.74492206 0.75133275]

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# Calculate accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# Training Accuracy: 1.00
# Test Accuracy: 0.74

# %%
'''scaler = StandardScaler()
scaler.fit(x_train)

def predict_attrition():
    # Collecting user input
    age = int(input("Enter Age: "))
    gender = int(input("Enter Gender (1 for Male, 0 for Female): "))
    years_at_company = int(input("Enter Years at Company: "))
    # Updated prompt to clarify input should be an integer
    job_role = int(input("Enter Job Role (0 for 'Education', 1 for 'Media', 2 for 'Healthcare', 3 for 'Technology', 4 for 'Finance'): "))
    monthly_income = int(input("Enter Monthly Income: "))
    education_level = int(input("Enter Education Level: "))
    number_of_promotions = int(input("Enter Number of Promotions: "))
    number_of_dependents = int(input("Enter Number of Dependents: "))
    job_satisfaction = int(input("Enter Job Satisfaction: "))
    work_life_balance = int(input("Enter Work-Life Balance: "))
    remote_work = int(input("Enter Remote Work: "))
    employee_recognition = int(input("Enter Employee Recognition: "))
    marital_status = int(input("Enter Marital Status: "))
    job_level = int(input("Enter Job Level: "))
    company_size = int(input("Enter Company Size: "))
    overtime = int(input("Enter Overtime: "))
    performance_rating = int(input("Enter Performance Rating: "))
    company_reputation = int(input("Enter Company Reputation: "))
    innovation_oppurtunities = int(input("Enter Innovation Opportunities: "))
    leadership_oppurtunities = int(input("Enter Leadership Opportunities: "))
    company_size=int(input("Enter Company Size: "))
    distance_from_home = int(input("Enter Distance from Home: "))



    #input_features = np.array([age, gender, years_at_company, job_role, monthly_income]).reshape(1, -1) # This line was only taking the first 5 features of the user input.
    input_features = np.array([age, gender, years_at_company, job_role, monthly_income, education_level, number_of_promotions, number_of_dependents, job_satisfaction, work_life_balance,  remote_work, employee_recognition, marital_status, job_level, company_size, overtime, performance_rating, company_reputation, innovation_oppurtunities, leadership_oppurtunities, company_size, distance_from_home ]).reshape(1, -1) #This line ensures all 22 features are used.

    # Standardize the input features
    input_features = scaler.transform(input_features)

    # Predict the probability of attrition
    prediction_proba = model.predict_proba(input_features)[0][1]  # Probability of attrition
    prediction = model.predict(input_features)[0]  # Binary prediction (0 or 1)

    # Output the prediction
    print(f"Probability of Attrition: {prediction_proba:.2f}")
    print(f"Predicted Attrition: {'Yes' if prediction == 1 else 'No'}")

# Call the prediction function
predict_attrition()1'''
# Out:
# 'scaler = StandardScaler()\nscaler.fit(x_train)\n\ndef predict_attrition():\n    # Collecting user input\n    age = int(input("Enter Age: "))\n    gender = int(input("Enter Gender (1 for Male, 0 for Female): "))\n    years_at_company = int(input("Enter Years at Company: "))\n    # Updated prompt to clarify input should be an integer\n    job_role = int(input("Enter Job Role (0 for \'Education\', 1 for \'Media\', 2 for \'Healthcare\', 3 for \'Technology\', 4 for \'Finance\'): ")) \n    monthly_income = int(input("Enter Monthly Income: "))\n    education_level = int(input("Enter Education Level: "))\n    number_of_promotions = int(input("Enter Number of Promotions: "))\n    number_of_dependents = int(input("Enter Number of Dependents: "))\n    job_satisfaction = int(input("Enter Job Satisfaction: "))\n    work_life_balance = int(input("Enter Work-Life Balance: "))\n    remote_work = int(input("Enter Remote Work: "))\n    employee_recognition = int(input("Enter Employee Recognition: "))
# ...

# %%
import pickle

# Assuming df is the DataFrame you want to save
if not df.empty:
    with open('my_dataframe.pickle', 'wb') as f:
        pickle.dump(df, f)
else:
    print("DataFrame is empty, not saving.")
